# %% [markdown]
# ## Imports

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Load dataset

# %%
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.boston_housing.load_data()
X_train.shape
# Out:
# (404, 13)

# %% [markdown]
# ### Data normalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print('X_train mean', np.mean(X_train))
print('X_train standard deviation', np.std(X_train))
# Out:
# X_train mean 2.6016254395785847e-15
# X_train standard deviation 0.9999999999999993

# %% [markdown]
# ## Learning
#
# ### Creating the Linear Regression

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(13,)))
model.add(tf.keras.layers.Dense(1, activation='linear', kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01)))

model.compile(loss='mse', optimizer='sgd', metrics=['mse'])

model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_25 (Dense)             (None, 1)                 14
# ...
# Total params: 14
# Trainable params: 14
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model.fit(X_train, y_train, epochs=10, batch_size=5, verbose=1)
# Out:
# Epoch 1/10
# 81/81 [==============================] - 0s 2ms/step - loss: 194.0698 - mse: 192.3868
# Epoch 2/10
# 81/81 [==============================] - 0s 2ms/step - loss: 35.7071 - mse: 31.3265
# Epoch 3/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.9527 - mse: 24.7855
# Epoch 4/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.7438 - mse: 24.4373
# Epoch 5/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.5065 - mse: 24.1758
# Epoch 6/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.0394 - mse: 23.6854
# Epoch 7/10
# 81/81 [==============================] - 0s 2ms/step - loss: 28.9605 - mse: 23.6441
# Epoch 8/10
# 81/81 [==============================] - 0s 2ms/step - loss: 28.9533 - mse: 23.5017
# Epoch 9/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.2532 - mse: 23.9065
# Epoch 10/10
# 81/81 [==============================] - 0s 2ms/step - loss: 29.1874 - mse: 23.7238

# %%
model.layers[0].get_weights()
# Out:
# [array([[-1.078587  ],
#         [ 1.0380073 ],
#         [-0.3189481 ],
#         [ 0.8537524 ],
#         [-2.1668959 ],
#         [ 2.6139574 ],
#         [ 0.06422882],
#         [-3.277074  ],
#         [ 1.727605  ],
#         [-1.0464463 ],
#         [-1.7700752 ],
#         [ 0.97402626],
#         [-3.81092   ]], dtype=float32), array([21.902077], dtype=float32)]

# %% [markdown]
# ## Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 26.9151 - mse: 21.6378

# %% [markdown]
# ## Imports

# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Load dataset

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ### Data normalization

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Reshaping

# %%
X_train = X_train.reshape(-1, 28*28)
X_train.shape
# Out:
# (60000, 784)

# %%
X_test = X_test.reshape(-1, 28*28)
X_test.shape
# Out:
# (10000, 784)

# %% [markdown]
# ## Learning

# %% [markdown]
# ### Building MLP

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=784, ))
model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

model.compile(optimizer='sgd', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
history = model.fit(X_train, y_train, batch_size=100, validation_split=0.1, epochs=20)
# Out:
# Epoch 1/20
# 540/540 [==============================] - 2s 4ms/step - loss: 1.1182 - sparse_categorical_accuracy: 0.6424 - val_loss: 0.7459 - val_sparse_categorical_accuracy: 0.7520
# Epoch 2/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.7460 - sparse_categorical_accuracy: 0.7494 - val_loss: 0.6289 - val_sparse_categorical_accuracy: 0.7867
# Epoch 3/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.6515 - sparse_categorical_accuracy: 0.7811 - val_loss: 0.5768 - val_sparse_categorical_accuracy: 0.8023
# Epoch 4/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.6035 - sparse_categorical_accuracy: 0.7978 - val_loss: 0.5412 - val_sparse_categorical_accuracy: 0.8178
# Epoch 5/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.5700 - sparse_categorical_accuracy: 0.8078 - val_loss: 0.5166 - val_sparse_categorical_accuracy: 0.8205
# Epoch 6/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.5456 - sparse_categorical_accuracy: 0.8156 - val_loss: 0.4993 - val_sparse_categorical_accuracy: 0.8287
# Epoch 7/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.5265 - sparse_categorical_accuracy: 0.8202 - val_loss: 0.4871 - val_sparse_categorical_accuracy: 0.8300
# Epoch 8/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.5116 - sparse_categorical_accuracy: 0.8262 - val_loss: 0.4735 - val_sparse_categorical_accuracy: 0.8338
# Epoch 9/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4975 - sparse_categorical_accuracy: 0.8293 - val_loss: 0.4658 - val_sparse_categorical_accuracy: 0.8343
# Epoch 10/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4868 - sparse_categorical_accuracy: 0.8331 - val_loss: 0.4587 - val_sparse_categorical_accuracy: 0.8393
# Epoch 11/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4781 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.4492 - val_sparse_categorical_accuracy: 0.8395
# Epoch 12/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4689 - sparse_categorical_accuracy: 0.8387 - val_loss: 0.4413 - val_sparse_categorical_accuracy: 0.8412
# Epoch 13/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4587 - sparse_categorical_accuracy: 0.8414 - val_loss: 0.4360 - val_sparse_categorical_accuracy: 0.8422
# Epoch 14/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4515 - sparse_categorical_accuracy: 0.8442 - val_loss: 0.4308 - val_sparse_categorical_accuracy: 0.8450
# Epoch 15/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4454 - sparse_categorical_accuracy: 0.8454 - val_loss: 0.4258 - val_sparse_categorical_accuracy: 0.8448
# Epoch 16/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4400 - sparse_categorical_accuracy: 0.8482 - val_loss: 0.4210 - val_sparse_categorical_accuracy: 0.8477
# Epoch 17/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4368 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.4164 - val_sparse_categorical_accuracy: 0.8502
# Epoch 18/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4307 - sparse_categorical_accuracy: 0.8509 - val_loss: 0.4124 - val_sparse_categorical_accuracy: 0.8508
# Epoch 19/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4253 - sparse_categorical_accuracy: 0.8517 - val_loss: 0.4088 - val_sparse_categorical_accuracy: 0.8517
# Epoch 20/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4198 - sparse_categorical_accuracy: 0.8536 - val_loss: 0.4070 - val_sparse_categorical_accuracy: 0.8560

# %% [markdown]
# ### Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_train, y_train, batch_size=100)
test_loss, test_accuracy = model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 600/600 [==============================] - 2s 3ms/step - loss: 0.3949 - sparse_categorical_accuracy: 0.8624
# 100/100 [==============================] - 0s 3ms/step - loss: 0.4321 - sparse_categorical_accuracy: 0.8481

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

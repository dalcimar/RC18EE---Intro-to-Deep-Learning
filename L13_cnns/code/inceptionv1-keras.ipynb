# %% [markdown]
# ## Imports

# %%
import numpy as np
import datetime
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar100

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Load dataset

# %%
(X_train, y_train), (X_test, y_test) = cifar100.load_data()

# %% [markdown]
# ### Data normalization

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

print(X_train.shape)
print(X_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %% [markdown]
# ## Learning

# %% [markdown]
# ### Building MLP

# %%
def inception_module(X, filters):
    
  # Retrieve Filters
  F1, F2, F3, F4, F5, F6 = filters

  conv_1x1 = tf.keras.layers.Conv2D(filters=F1, kernel_size=(1,1), padding='same', activation='relu')(X)
  
  conv_3x3 = tf.keras.layers.Conv2D(filters=F2, kernel_size=(1,1), padding='same', activation='relu')(X)
  conv_3x3 = tf.keras.layers.Conv2D(filters=F3, kernel_size=(3,3), padding='same', activation='relu')(conv_3x3)

  conv_5x5 = tf.keras.layers.Conv2D(filters=F4, kernel_size=(1,1), padding='same', activation='relu')(X)
  conv_5x5 = tf.keras.layers.Conv2D(filters=F5, kernel_size=(5,5), padding='same', activation='relu')(conv_5x5)

  pool_proj = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(1,1), padding='same')(X)
  pool_proj = tf.keras.layers.Conv2D(filters=F6, kernel_size=(1,1), padding='same', activation='relu')(pool_proj)

  X = tf.keras.layers.concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3)
  
  return X

# %%
X_input = tf.keras.layers.Input((32,32,3))
X = tf.keras.layers.experimental.preprocessing.Resizing(224,224)(X_input)

# Steam
X = tf.keras.layers.Conv2D(filters=64, kernel_size=(7,7), padding='same', strides=(2,2), activation='relu')(X)
X = tf.keras.layers.MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(X)
#X = tf.keras.layers.Conv2D(filters=64, kernel_size=(1,1), padding='same', strides=(1,1), activation='relu')(X)
X = tf.keras.layers.Conv2D(filters=192, kernel_size=(3,3), padding='same', strides=(1,1), activation='relu')(X)
X = tf.keras.layers.MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(X)

# Inception x2
X = inception_module(X, [64,96,128,16,32,32])
X = inception_module(X, [128,128,192,32,96,64])

# Maxpool
X = tf.keras.layers.MaxPool2D(pool_size=(3,3), padding='same', strides=(2,2))(X)

# Inception x1
X = inception_module(X, [192,96,208,16,48,64])

# Tower 1
X1 = tf.keras.layers.AveragePooling2D(pool_size=(5,5), strides=(3,3))(X)
x1 = tf.keras.layers.Conv2D(filters=128, kernel_size=(1,1), padding='same', activation='relu')(X1)
X1 = tf.keras.layers.Flatten()(X1)
X1 = tf.keras.layers.Dense(units=1024, activation='relu')(X1)
X1 = tf.keras.layers.Dropout(0.7)(X1)
X1 = tf.keras.layers.Dense(units=100, activation='softmax')(X1)

# Inception x3
X = inception_module(X, [160,112,224,24,64,64])
X = inception_module(X, [128,128,256,24,64,64])
X = inception_module(X, [112,144,288,32,64,64])

# Tower 2
X2 = tf.keras.layers.AveragePooling2D(pool_size=(5,5), strides=(3,3))(X)
X2 = tf.keras.layers.Conv2D(filters=128, kernel_size=(1,1), padding='same', activation='relu')(X2)
X2 = tf.keras.layers.Flatten()(X2)
X2 = tf.keras.layers.Dense(units=1024, activation='relu')(X2)
X2 = tf.keras.layers.Dropout(0.7)(X2)
X2 = tf.keras.layers.Dense(units=100, activation='softmax')(X2)

# Inception x1
X = inception_module(X, [256,160,320,32,128,128])

# Maxpool
X = tf.keras.layers.MaxPool2D(pool_size=(3, 3), padding='same', strides=(2,2))(X)

# Inception x2
X = inception_module(X, [256,160,320,32,128,128])
X = inception_module(X, [384,192,384,48,128,128])

X = tf.keras.layers.GlobalAveragePooling2D()(X)

X = tf.keras.layers.Dropout(0.4)(X)

X = tf.keras.layers.Dense(units=100, activation='softmax')(X)

model = tf.keras.models.Model(inputs=X_input, outputs=[X, X1, X2], name='ResNet50')

opt = tf.keras.optimizers.Adam()
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# resizing_9 (Resizing)           (None, 224, 224, 3)  0           input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_352 (Conv2D)             (None, 112, 112, 64) 9472        resizing_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_77 (MaxPooling2D) (None, 56, 56, 64)   0           conv2d_352[0][0]
# __________________________________________________________________________________________________
# conv2d_353 (Conv2D)             (None, 56, 56, 192)  110784      max_pooling2d_77[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_78 (MaxPooling2D) (None, 28, 28, 192)  0           conv2d_353[0][0]
# __________________________________________________________________________________________________
# conv2d_355 (Conv2D)             (None, 28, 28, 96)   18528       max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_357 (Conv2D)             (None, 28, 28, 16)   3088        max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_79 (MaxPooling2D) (None, 28, 28, 192)  0           max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_354 (Conv2D)             (None, 28, 28, 64)   12352       max_pooling2d_78[0][0]
# __________________________________________________________________________________________________
# conv2d_356 (Conv2D)             (None, 28, 28, 128)  110720      conv2d_355[0][0]
# __________________________________________________________________________________________________
# conv2d_358 (Conv2D)             (None, 28, 28, 32)   12832       conv2d_357[0][0]
# __________________________________________________________________________________________________
# conv2d_359 (Conv2D)             (None, 28, 28, 32)   6176        max_pooling2d_79[0][0]
# __________________________________________________________________________________________________
# concatenate_51 (Concatenate)    (None, 28, 28, 256)  0           conv2d_354[0][0]
#                                                                  conv2d_356[0][0]
#                                                                  conv2d_358[0][0]
#                                                                  conv2d_359[0][0]
# __________________________________________________________________________________________________
# conv2d_361 (Conv2D)             (None, 28, 28, 128)  32896       concatenate_51[0][0]
# __________________________________________________________________________________________________
# conv2d_363 (Conv2D)             (None, 28, 28, 32)   8224        concatenate_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_80 (MaxPooling2D) (None, 28, 28, 256)  0           concatenate_51[0][0]
# __________________________________________________________________________________________________
# conv2d_360 (Conv2D)             (None, 28, 28, 128)  32896       concatenate_51[0][0]
# __________________________________________________________________________________________________
# conv2d_362 (Conv2D)             (None, 28, 28, 192)  221376      conv2d_361[0][0]
# __________________________________________________________________________________________________
# conv2d_364 (Conv2D)             (None, 28, 28, 96)   76896       conv2d_363[0][0]
# __________________________________________________________________________________________________
# conv2d_365 (Conv2D)             (None, 28, 28, 64)   16448       max_pooling2d_80[0][0]
# __________________________________________________________________________________________________
# concatenate_52 (Concatenate)    (None, 28, 28, 480)  0           conv2d_360[0][0]
#                                                                  conv2d_362[0][0]
#                                                                  conv2d_364[0][0]
#                                                                  conv2d_365[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_81 (MaxPooling2D) (None, 14, 14, 480)  0           concatenate_52[0][0]
# __________________________________________________________________________________________________
# conv2d_367 (Conv2D)             (None, 14, 14, 96)   46176       max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_369 (Conv2D)             (None, 14, 14, 16)   7696        max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_82 (MaxPooling2D) (None, 14, 14, 480)  0           max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_366 (Conv2D)             (None, 14, 14, 192)  92352       max_pooling2d_81[0][0]
# __________________________________________________________________________________________________
# conv2d_368 (Conv2D)             (None, 14, 14, 208)  179920      conv2d_367[0][0]
# __________________________________________________________________________________________________
# conv2d_370 (Conv2D)             (None, 14, 14, 48)   19248       conv2d_369[0][0]
# __________________________________________________________________________________________________
# conv2d_371 (Conv2D)             (None, 14, 14, 64)   30784       max_pooling2d_82[0][0]
# __________________________________________________________________________________________________
# concatenate_53 (Concatenate)    (None, 14, 14, 512)  0           conv2d_366[0][0]
#                                                                  conv2d_368[0][0]
#                                                                  conv2d_370[0][0]
#                                                                  conv2d_371[0][0]
# __________________________________________________________________________________________________
# conv2d_374 (Conv2D)             (None, 14, 14, 112)  57456       concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_376 (Conv2D)             (None, 14, 14, 24)   12312       concatenate_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_83 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_373 (Conv2D)             (None, 14, 14, 160)  82080       concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_375 (Conv2D)             (None, 14, 14, 224)  226016      conv2d_374[0][0]
# __________________________________________________________________________________________________
# conv2d_377 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_376[0][0]
# __________________________________________________________________________________________________
# conv2d_378 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_83[0][0]
# __________________________________________________________________________________________________
# concatenate_54 (Concatenate)    (None, 14, 14, 512)  0           conv2d_373[0][0]
#                                                                  conv2d_375[0][0]
#                                                                  conv2d_377[0][0]
#                                                                  conv2d_378[0][0]
# __________________________________________________________________________________________________
# conv2d_380 (Conv2D)             (None, 14, 14, 128)  65664       concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_382 (Conv2D)             (None, 14, 14, 24)   12312       concatenate_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_84 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_379 (Conv2D)             (None, 14, 14, 128)  65664       concatenate_54[0][0]
# __________________________________________________________________________________________________
# conv2d_381 (Conv2D)             (None, 14, 14, 256)  295168      conv2d_380[0][0]
# __________________________________________________________________________________________________
# conv2d_383 (Conv2D)             (None, 14, 14, 64)   38464       conv2d_382[0][0]
# __________________________________________________________________________________________________
# conv2d_384 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_84[0][0]
# __________________________________________________________________________________________________
# concatenate_55 (Concatenate)    (None, 14, 14, 512)  0           conv2d_379[0][0]
#                                                                  conv2d_381[0][0]
#                                                                  conv2d_383[0][0]
#                                                                  conv2d_384[0][0]
# __________________________________________________________________________________________________
# conv2d_386 (Conv2D)             (None, 14, 14, 144)  73872       concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_388 (Conv2D)             (None, 14, 14, 32)   16416       concatenate_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_85 (MaxPooling2D) (None, 14, 14, 512)  0           concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_385 (Conv2D)             (None, 14, 14, 112)  57456       concatenate_55[0][0]
# __________________________________________________________________________________________________
# conv2d_387 (Conv2D)             (None, 14, 14, 288)  373536      conv2d_386[0][0]
# __________________________________________________________________________________________________
# conv2d_389 (Conv2D)             (None, 14, 14, 64)   51264       conv2d_388[0][0]
# __________________________________________________________________________________________________
# conv2d_390 (Conv2D)             (None, 14, 14, 64)   32832       max_pooling2d_85[0][0]
# __________________________________________________________________________________________________
# concatenate_56 (Concatenate)    (None, 14, 14, 528)  0           conv2d_385[0][0]
#                                                                  conv2d_387[0][0]
#                                                                  conv2d_389[0][0]
#                                                                  conv2d_390[0][0]
# __________________________________________________________________________________________________
# conv2d_393 (Conv2D)             (None, 14, 14, 160)  84640       concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_395 (Conv2D)             (None, 14, 14, 32)   16928       concatenate_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_86 (MaxPooling2D) (None, 14, 14, 528)  0           concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_392 (Conv2D)             (None, 14, 14, 256)  135424      concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_394 (Conv2D)             (None, 14, 14, 320)  461120      conv2d_393[0][0]
# __________________________________________________________________________________________________
# conv2d_396 (Conv2D)             (None, 14, 14, 128)  102528      conv2d_395[0][0]
# __________________________________________________________________________________________________
# conv2d_397 (Conv2D)             (None, 14, 14, 128)  67712       max_pooling2d_86[0][0]
# __________________________________________________________________________________________________
# concatenate_57 (Concatenate)    (None, 14, 14, 832)  0           conv2d_392[0][0]
#                                                                  conv2d_394[0][0]
#                                                                  conv2d_396[0][0]
#                                                                  conv2d_397[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_87 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_57[0][0]
# __________________________________________________________________________________________________
# conv2d_399 (Conv2D)             (None, 7, 7, 160)    133280      max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_401 (Conv2D)             (None, 7, 7, 32)     26656       max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_88 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_398 (Conv2D)             (None, 7, 7, 256)    213248      max_pooling2d_87[0][0]
# __________________________________________________________________________________________________
# conv2d_400 (Conv2D)             (None, 7, 7, 320)    461120      conv2d_399[0][0]
# __________________________________________________________________________________________________
# conv2d_402 (Conv2D)             (None, 7, 7, 128)    102528      conv2d_401[0][0]
# __________________________________________________________________________________________________
# conv2d_403 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_88[0][0]
# __________________________________________________________________________________________________
# concatenate_58 (Concatenate)    (None, 7, 7, 832)    0           conv2d_398[0][0]
#                                                                  conv2d_400[0][0]
#                                                                  conv2d_402[0][0]
#                                                                  conv2d_403[0][0]
# __________________________________________________________________________________________________
# conv2d_405 (Conv2D)             (None, 7, 7, 192)    159936      concatenate_58[0][0]
# __________________________________________________________________________________________________
# conv2d_407 (Conv2D)             (None, 7, 7, 48)     39984       concatenate_58[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_89 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_13 (AveragePo (None, 4, 4, 528)    0           concatenate_56[0][0]
# __________________________________________________________________________________________________
# conv2d_404 (Conv2D)             (None, 7, 7, 384)    319872      concatenate_58[0][0]
# __________________________________________________________________________________________________
# conv2d_406 (Conv2D)             (None, 7, 7, 384)    663936      conv2d_405[0][0]
# __________________________________________________________________________________________________
# conv2d_408 (Conv2D)             (None, 7, 7, 128)    153728      conv2d_407[0][0]
# __________________________________________________________________________________________________
# conv2d_409 (Conv2D)             (None, 7, 7, 128)    106624      max_pooling2d_89[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_12 (AveragePo (None, 4, 4, 512)    0           concatenate_53[0][0]
# __________________________________________________________________________________________________
# conv2d_391 (Conv2D)             (None, 4, 4, 128)    67712       average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_59 (Concatenate)    (None, 7, 7, 1024)   0           conv2d_404[0][0]
#                                                                  conv2d_406[0][0]
#                                                                  conv2d_408[0][0]
#                                                                  conv2d_409[0][0]
# __________________________________________________________________________________________________
# flatten_12 (Flatten)            (None, 8192)         0           average_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 2048)         0           conv2d_391[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_5 (Glo (None, 1024)         0           concatenate_59[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1024)         8389632     flatten_12[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 1024)         2098176     flatten_13[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 1024)         0           global_average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 1024)         0           dense_24[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 1024)         0           dense_26[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 100)          102500      dropout_18[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 100)          102500      dropout_16[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 100)          102500      dropout_17[0][0]
# ==================================================================================================
# Total params: 16,832,412
# Trainable params: 16,832,412
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Train

# %%
history = model.fit(X_train, [y_train, y_train, y_train], batch_size=100, validation_split=0.1, epochs=5)
# Out:
# Epoch 1/5
#   1/450 [..............................] - ETA: 0s - loss: 13.8115 - dense_28_loss: 4.6055 - dense_25_loss: 4.6009 - dense_27_loss: 4.6051 - dense_28_sparse_categorical_accuracy: 0.0100 - dense_25_sparse_categorical_accuracy: 0.0000e+00 - dense_27_sparse_categorical_accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-0e72dcd26710> in <module>()
# ----> 1 history = model.fit(X_train, [y_train, y_train, y_train], batch_size=100, validation_split=0.1, epochs=5)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_train, y_train, batch_size=100)
test_loss, test_accuracy = model.evaluate(X_test, y_test, batch_size=100)

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

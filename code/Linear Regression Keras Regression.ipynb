# %% [markdown]
# ## Imports

# %%
import numpy as np
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %% [markdown]
# ### Load dataset

# %%
from sklearn import datasets
diabetes = datasets.load_diabetes()

X = diabetes.data  # we only take the first two features.
y = diabetes.target

print('X.shape:', X.shape)
print('y.shape:', y.shape)

print(X[0:5,:])
print(y)
# Out:
# X.shape: (442, 10)
# y.shape: (442,)
# [[ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#   -0.04340085 -0.00259226  0.01990749 -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 -0.02632753 -0.00844872 -0.01916334
#    0.07441156 -0.03949338 -0.06833155 -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 -0.00567042 -0.04559945 -0.03419447
#   -0.03235593 -0.00259226  0.00286131 -0.02593034]
#  [-0.08906294 -0.04464164 -0.01159501 -0.03665608  0.01219057  0.02499059
#   -0.03603757  0.03430886  0.02268774 -0.00936191]
#  [ 0.00538306 -0.04464164 -0.03638469  0.02187239  0.00393485  0.01559614
#    0.00814208 -0.00259226 -0.03198764 -0.04664087]]
# [151.  75. 141. 206. 135.  97. 138.  63. 110. 310. 101.  69. 179. 185.
#  118. 171. 166. 144.  97. 168.  68.  49.  68. 245. 184. 202. 137.  85.
#  131. 283. 129.  59. 341.  87.  65. 102. 265. 276. 252.  90. 100.  55.
#   61.  92. 259.  53. 190. 142.  75. 142. 155. 225.  59. 104. 182. 128.
#   52.  37. 170. 170.  61. 144.  52. 128.  71. 163. 150.  97. 160. 178.
#   48. 270. 202. 111.  85.  42. 170. 200. 252. 113. 143.  51.  52. 210.
#   65. 141.  55. 134.  42. 111.  98. 164.  48.  96.  90. 162. 150. 279.
#   92.  83. 128. 102. 302. 198.  95.  53. 134. 144. 232.  81. 104.  59.
#  246. 297. 258. 229. 275. 281. 179. 200. 200. 173. 180.  84. 121. 161.
#   99. 109. 115. 268. 274. 158. 107.  83. 103. 272.  85. 280. 336. 281.
#  118. 317. 235.  60. 174. 259. 178. 128.  96. 126. 288.  88. 292.  71.
#  197. 186.  25.  84.  96. 195.  53. 217. 172. 131. 214.  59.  70. 220.
#  268. 152.  47.  74. 295. 101. 151. 127. 237. 225.  81. 151. 107.  64.
#  138. 185. 265. 101. 137. 143. 141.  79. 292. 178.  91. 116.  86. 122.
#   72. 129. 142.  90. 158.  39. 196. 222. 277.  99. 196. 202. 155.  77.
#  191.  70.  73.  49.  65. 263. 248. 296. 214. 185.  78.  93. 252. 150.
#   77. 208.  77. 108. 160.  53. 220. 154. 259.  90. 246. 124.  67.  72.
#  257. 262. 275. 177.  71.  47. 187. 125.  78.  51. 258. 215. 303. 243.
#   91. 150. 310. 153. 346.  63.  89.  50.  39. 103. 308. 116. 145.  74.
#   45. 115. 264.  87. 202. 127. 182. 241.  66.  94. 283.  64. 102. 200.
#  265.  94. 230. 181. 156. 233.  60. 219.  80.  68. 332. 248.  84. 200.
#   55.  85.  89.  31. 129.  83. 275.  65. 198. 236. 253. 124.  44. 172.
#  114. 142. 109. 180. 144. 163. 147.  97. 220. 190. 109. 191. 122. 230.
#  242. 248. 249. 192. 131. 237.  78. 135. 244. 199. 270. 164.  72.  96.
#  306.  91. 214.  95. 216. 263. 178. 113. 200. 139. 139.  88. 148.  88.
#  243.  71.  77. 109. 272.  60.  54. 221.  90. 311. 281. 182. 321.  58.
#  262. 206. 233. 242. 123. 167.  63. 197.  71. 168. 140. 217. 121. 235.
#  245.  40.  52. 104. 132.  88.  69. 219.  72. 201. 110.  51. 277.  63.
#  118.  69. 273. 258.  43. 198. 242. 232. 175.  93. 168. 275. 293. 281.
#   72. 140. 189. 181. 209. 136. 261. 113. 131. 174. 257.  55.  84.  42.
#  146. 212. 233.  91. 111. 152. 120.  67. 310.  94. 183.  66. 173.  72.
#   49.  64.  48. 178. 104. 132. 220.  57.]

# %% [markdown]
# ### Cross validation

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=123)

print('X_train.shape', X_train.shape)
print('y_train.shape', y_train.shape)
print('X_test.shape', X_test.shape)
print('y_test.shape', y_test.shape)
# Out:
# X_train.shape (265, 10)
# y_train.shape (265,)
# X_test.shape (177, 10)
# y_test.shape (177,)

# %% [markdown]
# ### Data normalization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print('X_train mean', np.mean(X_train))
print('X_train standard deviation', np.std(X_train))
# Out:
# X_train mean 4.558198682234605e-17
# X_train standard deviation 1.0

# %% [markdown]
# ## Learning
#
# ### Creating the Linear Regression

# %%
X_input = tf.keras.layers.Input([10])
y_pred = tf.keras.layers.Dense(units=1, activation='linear', kernel_initializer='zeros', use_bias='yes')(X_input)

model = tf.keras.models.Model(inputs=X_input, outputs=y_pred)

model.compile(loss='mse', metrics='mean_absolute_error', optimizer=tf.keras.optimizers.SGD(learning_rate=0.05))

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 10)]              0
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
model.fit(X_train, y_train, epochs=10, batch_size=5, verbose=1)
# Out:
# Epoch 1/10
# 53/53 [==============================] - 0s 2ms/step - loss: 6202.3364 - mean_absolute_error: 60.6963
# Epoch 2/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3042.4653 - mean_absolute_error: 44.8672
# Epoch 3/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3308.3433 - mean_absolute_error: 45.4378
# Epoch 4/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3264.4019 - mean_absolute_error: 46.0356
# Epoch 5/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3220.1631 - mean_absolute_error: 45.4680
# Epoch 6/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3293.0520 - mean_absolute_error: 46.2192
# Epoch 7/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3274.6965 - mean_absolute_error: 46.1370
# Epoch 8/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3271.9377 - mean_absolute_error: 46.0222
# Epoch 9/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3421.1406 - mean_absolute_error: 47.1847
# Epoch 10/10
# 53/53 [==============================] - 0s 2ms/step - loss: 3492.1077 - mean_absolute_error: 47.0272

# %% [markdown]
# ## Evaluation

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 6/6 [==============================] - 0s 56ms/step - loss: 3188.6094 - mse: 3188.6094

# %%
y_test_pred = model.predict(X_test)
y_test_pred = np.reshape(y_test_pred,-1)
print(y_test_pred)
# Out:
# 6/6 [==============================] - 1s 149ms/step
# [158.13414  148.29541  242.56029  157.57875  163.08678  160.55289
#  258.4245   127.894806 109.237976  93.15411  109.89389  185.08598
#  169.37833  223.38203  257.21094  213.79214  110.043274 121.122475
#  200.76886  215.80327  176.08069  245.63914  173.49097   58.54216
#  118.13898  222.61967  104.627365  84.3351   144.20905  173.99265
#   97.71388  270.38873  205.20152  231.0007   210.5221    74.104706
#   88.50321   61.648224 261.4913   106.559906 228.16093   61.25122
#   74.55077  128.85567  105.78758  250.96135   39.63472   72.90023
#   87.70192  241.53543   50.787857 117.580414 185.49419  226.8157
#  134.65302  206.50938  242.89117  202.3338   202.63248  179.67888
#  144.87395  112.01573  236.73985  216.3715   211.72972   22.856934
#   41.243652 174.10963  131.2037    83.84463  123.16682   53.45137
#  153.71341  197.26524  100.20146  182.48819  134.99484  157.48267
#   80.27035   65.84424   34.978683 172.1817   118.846436 249.99121
#  312.81458  184.1215   216.73547   41.45935  123.86453  147.57579
#  173.41219   70.64083  181.93254  169.61699   92.5125   270.71558
#  103.9136   255.3047   139.16704  151.50636   66.89527   66.923874
#   93.08252  191.30252  207.10777   88.25664  136.11612  153.80586
#  196.27911  255.35957   98.40228  144.34558  117.532364  40.07499
#  118.94621   53.060265 196.84355   46.197456 197.43983  197.26323
#  142.66106  162.88647  154.76694   94.06278  221.31744  249.56633
#  237.83038  200.86497   55.695114 288.7196   111.68152  157.44484
#  141.19398   94.71147  155.78345  185.50258   21.202652 220.35358
#   72.94451  238.29178  191.73907  226.2096   166.17941  180.40656
#  280.50873  168.66687  212.52823  178.20497  111.41614  152.64034
#  192.37991   89.67522  128.58191  124.94672  182.8402   218.01959
#  120.03621  176.28723  102.43756   96.144165 109.28114  289.79916
#  112.94051  168.0788   145.3972    40.01748   58.688034 129.91304
#  167.05948  261.93808   98.89552  168.80768  285.5438    79.939514
#   81.924416 157.11899  175.86734 ]
